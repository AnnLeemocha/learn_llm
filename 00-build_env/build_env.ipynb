# %% [markdown]
# ### NVIDIA 驅動程式

# %% [markdown]
# 1. 查看可以安裝的 Driver 版本：

# %%
# %%bash
#
# apt search nvidia-driver
# # 或者
# apt-cache search nvidia-driver

# %% [markdown]
# 2. 透過 apt 直接安裝即可：
#
# **安裝完之後重新開機，然後開始祈禱電腦能順利重開。**

# %%
# %%bash
#
# # 以安裝 535 版為例
# sudo apt install nvidia-driver-535

# %%
# %%bash
#
# # 可以考慮將驅動程式的版本鎖定起來，避免自動更新
# sudo apt-mark hold nvidia-driver-535
# sudo apt-mark hold libnvidia-compute-535

# %% [markdown]
# 3. 確認是否安裝成功：

# %%
# %%bash
#
# # 如果你的電腦能夠順利重開
# nvidia-smi
# Out:
# Thu May 15 16:57:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.133.20             Driver Version: 570.133.20     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA RTX A6000               Off |   00000000:47:00.0 Off |                  Off |
# | 30%   45C    P0             88W /  300W |    3684MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA RTX A6000               Off |   00000000:72:00.0 Off |                  Off |
# | 30%   35C    P8             17W /  300W |      18MiB /  49140MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1403      G   /usr/lib/xorg/Xorg                       46MiB |
# |    0   N/A  N/A            1613      G   /usr/bin/gnome-shell                     16MiB |
# |    0   N/A  N/A         1682336      C   milvus                                 1284MiB |
# |    0   N/A  N/A         2098238      C   ...3/envs/py311-bpest/bin/python        550MiB |
# |    0   N/A  N/A         2098239      C   ...3/envs/py311-bpest/bin/python        550MiB |
# |    0   N/A  N/A         2098240      C   ...3/envs/py311-bpest/bin/python        550MiB |
# |    0   N/A  N/A         2098241      C   ...3/envs/py311-bpest/bin/python        634MiB |
# |    1   N/A  N/A            1403      G   /usr/lib/xorg/Xorg                        4MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### 使用 Anaconda / Miniconda / Condaforge 建立虛擬環境管理
# Conda 不僅能用來管理 Python 套件，也能管理 Python 本身的版本以及 CUDA 的版本之類的。
# * Anaconda：
#     * 安裝路徑：https://github.com/conda-forge/miniforge/releases/latest/download/
#     * 檔案格式：`Anaconda3-2024.10-1-Linux-${ARCH}.sh`
# * Miniconda
#     * 安裝路徑：https://repo.anaconda.com/miniconda/
#     * 檔案格式：`Miniconda3-latest-Linux-${ARCH}.sh`
# * Condaforge
#     * 安裝路徑：https://github.com/conda-forge/miniforge/releases/latest/download/
#     * 檔案格式：`Miniforge3-Linux-${ARCH}.sh`

# %% [markdown]
# 1. 安裝 Conda

# %%
# %%bash
#
# # Download the Conda installation script
# wget https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
#
# # Grant execution permissions to the installation script
# chmod +x Miniforge3-Linux-x86_64.sh
#
# # Install Conda (-b: 背景執行，-p 指定安裝路徑)
# ./Miniforge3-Linux-x86_64.sh -b
# # ./Miniforge3-Linux-x86_64.sh -b -p "/opt/miniforge3"

# %% [markdown]
# 2. 啟用 Conda 並進行初始化

# %%
# %%bash
#
# # Activate Conda
# source ~/miniforge3/etc/profile.d/conda.sh
#
# # Initialize Conda
# conda init
#
# # Load the .bashrc configuration.
# source ~/.bashrc
#
# # 會自動進入 conda (base) 環境，可以離開 base 環境
# conda deactivate
#
# # 可以關閉自動開啟 base 環境
# conda config --set auto_activate_base false

# %% [markdown]
# 3. 創建虛擬環境

# %%
# %%bash
#
# # 創建虛擬環境： (llm_env_py311)
# conda create -n llm_env_py311 python=3.11
#
# # 查看已建立的虛擬環境：
# conda env list

# %% [markdown]
# 4. 啟用創建好的虛擬環境

# %%
# %%bash
#
# # 啟用 base
# conda activate
#
# # 啟用 llm_env_py311
# conda activate llm_env_py311

# %% [markdown]
# ### 使用 python 的 venv 套件

# %% [markdown]
# 1. 安裝套件

# %%
# %%bash
# sudo apt update
# # 根據目前 Python 版本安裝對應的 venv 套件
# sudo apt install python3.12-venv -y

# %% [markdown]
# 2. 建立虛擬環境

# %%
# %%bash
# # make sure you the venv folder was created at project root.
# python -m venv ./venv
# # or
# python3 -m venv ./venv

# %% [markdown]
# 3. 執行虛擬環境

# %%
# %%bash
# ./venv/Scripts/activate
# # or
# source venv/bin/activate

# %% [markdown]
#   如果出現錯誤
# ```
# + .\venv\Scripts\activate
# + ~~~~~~~~~~~~~~~~~~~~~~~
#    + CategoryInfo          : SecurityError: (:) [], PSSecurityException
#    + FullyQualifiedErrorId : UnauthorizedAccess
# ```
# 可以先將執行政策改為允許啟動虛擬環境腳本，然後再啟動虛擬環境：

# %%
# （臨時更改）— 最安全建議
Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope Process

# %%
# （永久更改）— 如果你常使用虛擬環境
Set-ExecutionPolicy -ExecutionPolicy RemoteSigned -Scope CurrentUser

# %% [markdown]
# 4. 測試

# %%
print("Hello World!")
# Out:
# Running cells with 'llm_env' requires the ipykernel package.
#
#
#
# Run the following command to install 'ipykernel' into the Python environment.
#
#
#
# Command: 'conda install -n llm_env ipykernel --update-deps --force-reinstall'

# %% [markdown]
# ### 安裝 CUDA
# * 推薦可以參考 [PyTorch 官網](https://pytorch.org/get-started/locally/)目前支援到哪個版本，來決定要安裝哪個 CUDA 版本。
#     * 因為很多套件開發者也都是跟隨 PyTorch 的版本在跑。
#     * 只是參考，一切以應用需求為主。
# * 可以在 Anaconda 的[頁面](https://anaconda.org/nvidia/cuda-toolkit)上查看目前可以安裝哪些版本的 CUDA 可以安裝。
# * 除了 `cuda` 以外，還有個名稱為 `cuda-toolkit` 的套件，兩者其實都會幫你安裝 CUDA 函式庫。
#     * 選擇安裝 `cuda` 套件的話，會比 `cuda-toolkit` 多出 `cuda`, `cuda-demo-suite`, `cuda-runtime` 等三個項目。
#     * 實際上只有 `cuda-demo-suite` 套件會多安裝一些新檔案。
#     * 不管安裝 `cuda` 或 `cuda-toolkit` 都是可以的，但推薦按照 [NVIDIA 官方文件](https://docs.nvidia.com/cuda/cuda-installation-guide-linux/index.html#conda-installation)的建議安裝 `cuda` 套件即可。

# %%
# %%bash
#
# # 安裝標籤為 nvidia/label/cuda-12.1.1 的 cuda 套件。
# conda install -y nvidia/label/cuda-12.1.1::cuda
# Out:
# Channels:
#  - conda-forge
#  - nvidia/label/cuda-12.1.1
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.3.0
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
# ## Package Plan ##
#
#   environment location: /home/ann/.conda/envs/llm_env
#
#   added / updated specs:
#     - nvidia/label/cuda-12.1.1::cuda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.14            |       hb9d3cd8_0         553 KB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     binutils-2.43              |       h4852527_4          34 KB  conda-forge
#     binutils_impl_linux-64-2.43|       h4bf12b8_4         5.8 MB  conda-forge
#     binutils_linux-64-2.43     |       h4852527_4          35 KB  conda-forge
#     c-compiler-1.9.0           |       h2b85faf_0           6 KB  conda-forge
#     cuda-12.1.1                |                0           1 KB  nvidia/label/cuda-12.1.1
#     cuda-cccl_linux-64-12.9.27 |       ha770c72_0         1.1 MB  conda-forge
#     cuda-command-line-tools-12.9.0|       ha770c72_0          20 KB  conda-forge
#     cuda-compiler-12.9.0       |       hbad6d8a_0          20 KB  conda-forge
#     cuda-crt-dev_linux-64-12.9.41|       ha770c72_0          92 KB  conda-forge
#     cuda-crt-tools-12.9.41     |       ha770c72_0          28 KB  conda-forge
#     cuda-cudart-12.9.37        |       h5888daf_0          23 KB  conda-forge
#     cuda-cudart-dev-12.9.37    |       h5888daf_0          23 KB  conda-forge
#     cuda-cudart-dev_linux-64-12.9.37|       h3f2d84a_0         380 KB  conda-forge
#     cuda-cudart-static-12.9.37 |       h5888daf_0          23 KB  conda-forge
#     cuda-cudart-static_linux-64-12.9.37|       h3f2d84a_0         1.1 MB  conda-forge
#     cuda-cudart_linux-64-12.9.37|       h3f2d84a_0         193 KB  conda-forge
#     cuda-cuobjdump-12.9.26     |       hbd13f7d_0         239 KB  conda-forge
#     cuda-cupti-12.9.19         |       h9ab20c4_0         1.8 MB  conda-forge
#     cuda-cupti-dev-12.9.19     |       h9ab20c4_0         4.4 MB  conda-forge
#     cuda-cuxxfilt-12.9.19      |       hbd13f7d_0         212 KB  conda-forge
#     cuda-demo-suite-12.1.105   |                0         5.0 MB  nvidia/label/cuda-12.1.1
#     cuda-driver-dev-12.9.37    |       h5888daf_0          22 KB  conda-forge
#     cuda-driver-dev_linux-64-12.9.37|       h3f2d84a_0          37 KB  conda-forge
#     cuda-gdb-12.9.19           |       ha677faa_0         378 KB  conda-forge
#     cuda-libraries-12.9.0      |       ha770c72_0          20 KB  conda-forge
#     cuda-libraries-dev-12.9.0  |       ha770c72_0          20 KB  conda-forge
#     cuda-nsight-12.9.19        |       h7938cbb_0       113.2 MB  conda-forge
#     cuda-nvcc-12.9.41          |       hcdd1206_0          24 KB  conda-forge
#     cuda-nvcc-dev_linux-64-12.9.41|       he91c749_0        13.8 MB  conda-forge
#     cuda-nvcc-impl-12.9.41     |       h85509e4_0          26 KB  conda-forge
#     cuda-nvcc-tools-12.9.41    |       he02047a_0        26.2 MB  conda-forge
#     cuda-nvcc_linux-64-12.9.41 |       he0b4e1d_0          26 KB  conda-forge
#     cuda-nvdisasm-12.9.19      |       hbd13f7d_0         5.3 MB  conda-forge
#     cuda-nvml-dev-12.9.40      |       hbd13f7d_0         140 KB  conda-forge
#     cuda-nvprof-12.9.19        |       hcf8d014_0         2.5 MB  conda-forge
#     cuda-nvprune-12.9.19       |       hbd13f7d_0          70 KB  conda-forge
#     cuda-nvrtc-12.9.41         |       h5888daf_0        64.1 MB  conda-forge
#     cuda-nvrtc-dev-12.9.41     |       h5888daf_0          35 KB  conda-forge
#     cuda-nvtx-12.9.19          |       h5888daf_0          29 KB  conda-forge
#     cuda-nvvm-dev_linux-64-12.9.41|       ha770c72_0          26 KB  conda-forge
#     cuda-nvvm-impl-12.9.41     |       he02047a_0        20.4 MB  conda-forge
#     cuda-nvvm-tools-12.9.41    |       he02047a_0        23.1 MB  conda-forge
#     cuda-nvvp-12.9.19          |       hbd13f7d_0       112.4 MB  conda-forge
#     cuda-opencl-12.9.19        |       h5888daf_0          30 KB  conda-forge
#     cuda-opencl-dev-12.9.19    |       h5888daf_0          95 KB  conda-forge
#     cuda-profiler-api-12.9.19  |       h7938cbb_0          23 KB  conda-forge
#     cuda-runtime-12.9.0        |       ha804496_0          20 KB  conda-forge
#     cuda-sanitizer-api-12.9.27 |       hcf8d014_0         8.7 MB  conda-forge
#     cuda-toolkit-12.9.0        |       ha804496_0          20 KB  conda-forge
#     cuda-tools-12.9.0          |       ha770c72_0          20 KB  conda-forge
#     cuda-version-12.9          |       h4f385c5_3          21 KB  conda-forge
#     cuda-visual-tools-12.9.0   |       ha770c72_0          20 KB  conda-forge
#     cxx-compiler-1.9.0         |       h1a2810e_0           6 KB  conda-forge
#     dbus-1.13.6                |       h5008d03_3         604 KB  conda-forge
#     expat-2.7.0                |       h5888daf_0         137 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     gcc-13.3.0                 |       h9576a4e_2          54 KB  conda-forge
#     gcc_impl_linux-64-13.3.0   |       h1e990d8_2        63.7 MB  conda-forge
#     gcc_linux-64-13.3.0        |      hc28eda2_10          32 KB  conda-forge
#     gds-tools-1.14.0.30        |       h5888daf_0        37.8 MB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     gxx-13.3.0                 |       h9576a4e_2          53 KB  conda-forge
#     gxx_impl_linux-64-13.3.0   |       hae580e1_2        12.7 MB  conda-forge
#     gxx_linux-64-13.3.0        |      h6834431_10          30 KB  conda-forge
#     kernel-headers_linux-64-3.10.0|      he073ed8_18         921 KB  conda-forge
#     libcap-2.75                |       h39aace5_0         118 KB  conda-forge
#     libcublas-12.9.0.13        |       h9ab20c4_0       445.8 MB  conda-forge
#     libcublas-dev-12.9.0.13    |       h9ab20c4_0          90 KB  conda-forge
#     libcufft-11.4.0.6          |       h5888daf_0       154.3 MB  conda-forge
#     libcufft-dev-11.4.0.6      |       h5888daf_0          33 KB  conda-forge
#     libcufile-1.14.0.30        |       h628e99a_0         948 KB  conda-forge
#     libcufile-dev-1.14.0.30    |       h5888daf_0          36 KB  conda-forge
#     libcurand-10.3.10.19       |       h9ab20c4_0        44.0 MB  conda-forge
#     libcurand-dev-10.3.10.19   |       h9ab20c4_0         248 KB  conda-forge
#     libcusolver-11.7.4.40      |       h9ab20c4_0       192.4 MB  conda-forge
#     libcusolver-dev-11.7.4.40  |       h9ab20c4_0          60 KB  conda-forge
#     libcusparse-12.5.9.5       |       h5888daf_0       199.2 MB  conda-forge
#     libcusparse-dev-12.5.9.5   |       h5888daf_0          52 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libgcc-devel_linux-64-13.3.0|     hc03c837_102         2.5 MB  conda-forge
#     libgcrypt-lib-1.11.1       |       hb9d3cd8_0         577 KB  conda-forge
#     libglib-2.84.1             |       h3618099_1         3.8 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libgpg-error-1.55          |       h3f2d84a_0         305 KB  conda-forge
#     libnl-3.11.0               |       hb9d3cd8_0         724 KB  conda-forge
#     libnpp-12.4.0.27           |       h9ab20c4_0       167.2 MB  conda-forge
#     libnpp-dev-12.4.0.27       |       h9ab20c4_0         452 KB  conda-forge
#     libnuma-2.0.18             |       h4ab18f5_2          42 KB  conda-forge
#     libnvfatbin-12.9.19        |       h5888daf_0         799 KB  conda-forge
#     libnvfatbin-dev-12.9.19    |       h5888daf_0          27 KB  conda-forge
#     libnvjitlink-12.9.41       |       h5888daf_0        29.1 MB  conda-forge
#     libnvjitlink-dev-12.9.41   |       h5888daf_0          26 KB  conda-forge
#     libnvjpeg-12.4.0.16        |       h5888daf_0         3.4 MB  conda-forge
#     libnvjpeg-dev-12.4.0.16    |       ha770c72_0          32 KB  conda-forge
#     libopengl-1.7.0            |       ha4b6fd6_2          50 KB  conda-forge
#     libpng-1.6.47              |       h943b412_0         282 KB  conda-forge
#     libsanitizer-13.3.0        |       he8ea267_2         4.0 MB  conda-forge
#     libstdcxx-devel_linux-64-13.3.0|     hc03c837_102        12.3 MB  conda-forge
#     libsystemd0-257.4          |       h4e0b6ca_1         477 KB  conda-forge
#     libudev1-257.4             |       hbe16f8c_1         141 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxkbcommon-1.9.2         |       h65c71a3_0         660 KB  conda-forge
#     libxkbfile-1.1.0           |       h166bdaf_1         111 KB  conda-forge
#     nsight-compute-2025.2.0.11 |       hb5ebaad_0       318.5 MB  conda-forge
#     nspr-4.36                  |       h5888daf_0         225 KB  conda-forge
#     nss-3.111                  |       h159eef7_0         1.9 MB  conda-forge
#     ocl-icd-2.3.3              |       hb9d3cd8_0         104 KB  conda-forge
#     opencl-headers-2024.10.24  |       h5888daf_0          53 KB  conda-forge
#     pcre2-10.45                |       hc749103_0         1.1 MB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     rdma-core-57.0             |       h5888daf_0         1.2 MB  conda-forge
#     sysroot_linux-64-2.17      |      h0157908_18        14.5 MB  conda-forge
#     wayland-1.23.1             |       h3e06ad9_1         314 KB  conda-forge
#     xcb-util-0.4.1             |       hb711507_2          19 KB  conda-forge
#     xcb-util-cursor-0.1.5      |       hb9d3cd8_0          20 KB  conda-forge
#     xcb-util-image-0.4.0       |       hb711507_2          24 KB  conda-forge
#     xcb-util-keysyms-0.4.1     |       hb711507_0          14 KB  conda-forge
#     xcb-util-renderutil-0.3.10 |       hb711507_0          17 KB  conda-forge
#     xcb-util-wm-0.4.2          |       hb711507_0          50 KB  conda-forge
#     xkeyboard-config-2.44      |       hb9d3cd8_0         384 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxcomposite-0.4.6   |       hb9d3cd8_2          13 KB  conda-forge
#     xorg-libxdamage-1.1.6      |       hb9d3cd8_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.1       |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxi-1.8.2           |       hb9d3cd8_0          46 KB  conda-forge
#     xorg-libxrandr-1.5.4       |       hb9d3cd8_0          29 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxtst-1.2.5         |       hb9d3cd8_3          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        2.09 GB
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.14-hb9d3cd8_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   binutils           conda-forge/linux-64::binutils-2.43-h4852527_4
#   binutils_impl_lin~ conda-forge/linux-64::binutils_impl_linux-64-2.43-h4bf12b8_4
#   binutils_linux-64  conda-forge/linux-64::binutils_linux-64-2.43-h4852527_4
#   c-compiler         conda-forge/linux-64::c-compiler-1.9.0-h2b85faf_0
#   cuda               nvidia/label/cuda-12.1.1/linux-64::cuda-12.1.1-0
#   cuda-cccl_linux-64 conda-forge/noarch::cuda-cccl_linux-64-12.9.27-ha770c72_0
#   cuda-command-line~ conda-forge/linux-64::cuda-command-line-tools-12.9.0-ha770c72_0
#   cuda-compiler      conda-forge/noarch::cuda-compiler-12.9.0-hbad6d8a_0
#   cuda-crt-dev_linu~ conda-forge/noarch::cuda-crt-dev_linux-64-12.9.41-ha770c72_0
#   cuda-crt-tools     conda-forge/linux-64::cuda-crt-tools-12.9.41-ha770c72_0
#   cuda-cudart        conda-forge/linux-64::cuda-cudart-12.9.37-h5888daf_0
#   cuda-cudart-dev    conda-forge/linux-64::cuda-cudart-dev-12.9.37-h5888daf_0
#   cuda-cudart-dev_l~ conda-forge/noarch::cuda-cudart-dev_linux-64-12.9.37-h3f2d84a_0
#   cuda-cudart-static conda-forge/linux-64::cuda-cudart-static-12.9.37-h5888daf_0
#   cuda-cudart-stati~ conda-forge/noarch::cuda-cudart-static_linux-64-12.9.37-h3f2d84a_0
#   cuda-cudart_linux~ conda-forge/noarch::cuda-cudart_linux-64-12.9.37-h3f2d84a_0
#   cuda-cuobjdump     conda-forge/linux-64::cuda-cuobjdump-12.9.26-hbd13f7d_0
#   cuda-cupti         conda-forge/linux-64::cuda-cupti-12.9.19-h9ab20c4_0
#   cuda-cupti-dev     conda-forge/linux-64::cuda-cupti-dev-12.9.19-h9ab20c4_0
#   cuda-cuxxfilt      conda-forge/linux-64::cuda-cuxxfilt-12.9.19-hbd13f7d_0
#   cuda-demo-suite    nvidia/label/cuda-12.1.1/linux-64::cuda-demo-suite-12.1.105-0
#   cuda-driver-dev    conda-forge/linux-64::cuda-driver-dev-12.9.37-h5888daf_0
#   cuda-driver-dev_l~ conda-forge/noarch::cuda-driver-dev_linux-64-12.9.37-h3f2d84a_0
#   cuda-gdb           conda-forge/linux-64::cuda-gdb-12.9.19-ha677faa_0
#   cuda-libraries     conda-forge/linux-64::cuda-libraries-12.9.0-ha770c72_0
#   cuda-libraries-dev conda-forge/linux-64::cuda-libraries-dev-12.9.0-ha770c72_0
#   cuda-nsight        conda-forge/linux-64::cuda-nsight-12.9.19-h7938cbb_0
#   cuda-nvcc          conda-forge/linux-64::cuda-nvcc-12.9.41-hcdd1206_0
#   cuda-nvcc-dev_lin~ conda-forge/noarch::cuda-nvcc-dev_linux-64-12.9.41-he91c749_0
#   cuda-nvcc-impl     conda-forge/linux-64::cuda-nvcc-impl-12.9.41-h85509e4_0
#   cuda-nvcc-tools    conda-forge/linux-64::cuda-nvcc-tools-12.9.41-he02047a_0
#   cuda-nvcc_linux-64 conda-forge/linux-64::cuda-nvcc_linux-64-12.9.41-he0b4e1d_0
#   cuda-nvdisasm      conda-forge/linux-64::cuda-nvdisasm-12.9.19-hbd13f7d_0
#   cuda-nvml-dev      conda-forge/linux-64::cuda-nvml-dev-12.9.40-hbd13f7d_0
#   cuda-nvprof        conda-forge/linux-64::cuda-nvprof-12.9.19-hcf8d014_0
#   cuda-nvprune       conda-forge/linux-64::cuda-nvprune-12.9.19-hbd13f7d_0
#   cuda-nvrtc         conda-forge/linux-64::cuda-nvrtc-12.9.41-h5888daf_0
#   cuda-nvrtc-dev     conda-forge/linux-64::cuda-nvrtc-dev-12.9.41-h5888daf_0
#   cuda-nvtx          conda-forge/linux-64::cuda-nvtx-12.9.19-h5888daf_0
#   cuda-nvvm-dev_lin~ conda-forge/noarch::cuda-nvvm-dev_linux-64-12.9.41-ha770c72_0
#   cuda-nvvm-impl     conda-forge/linux-64::cuda-nvvm-impl-12.9.41-he02047a_0
#   cuda-nvvm-tools    conda-forge/linux-64::cuda-nvvm-tools-12.9.41-he02047a_0
#   cuda-nvvp          conda-forge/linux-64::cuda-nvvp-12.9.19-hbd13f7d_0
#   cuda-opencl        conda-forge/linux-64::cuda-opencl-12.9.19-h5888daf_0
#   cuda-opencl-dev    conda-forge/linux-64::cuda-opencl-dev-12.9.19-h5888daf_0
#   cuda-profiler-api  conda-forge/linux-64::cuda-profiler-api-12.9.19-h7938cbb_0
#   cuda-runtime       conda-forge/noarch::cuda-runtime-12.9.0-ha804496_0
#   cuda-sanitizer-api conda-forge/linux-64::cuda-sanitizer-api-12.9.27-hcf8d014_0
#   cuda-toolkit       conda-forge/noarch::cuda-toolkit-12.9.0-ha804496_0
#   cuda-tools         conda-forge/linux-64::cuda-tools-12.9.0-ha770c72_0
#   cuda-version       conda-forge/noarch::cuda-version-12.9-h4f385c5_3
#   cuda-visual-tools  conda-forge/linux-64::cuda-visual-tools-12.9.0-ha770c72_0
#   cxx-compiler       conda-forge/linux-64::cxx-compiler-1.9.0-h1a2810e_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-h5008d03_3
#   expat              conda-forge/linux-64::expat-2.7.0-h5888daf_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   gcc                conda-forge/linux-64::gcc-13.3.0-h9576a4e_2
#   gcc_impl_linux-64  conda-forge/linux-64::gcc_impl_linux-64-13.3.0-h1e990d8_2
#   gcc_linux-64       conda-forge/linux-64::gcc_linux-64-13.3.0-hc28eda2_10
#   gds-tools          conda-forge/linux-64::gds-tools-1.14.0.30-h5888daf_0
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   gxx                conda-forge/linux-64::gxx-13.3.0-h9576a4e_2
#   gxx_impl_linux-64  conda-forge/linux-64::gxx_impl_linux-64-13.3.0-hae580e1_2
#   gxx_linux-64       conda-forge/linux-64::gxx_linux-64-13.3.0-h6834431_10
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   kernel-headers_li~ conda-forge/noarch::kernel-headers_linux-64-3.10.0-he073ed8_18
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   krb5               conda-forge/linux-64::krb5-1.21.3-h659f571_0
#   libcap             conda-forge/linux-64::libcap-2.75-h39aace5_0
#   libcublas          conda-forge/linux-64::libcublas-12.9.0.13-h9ab20c4_0
#   libcublas-dev      conda-forge/linux-64::libcublas-dev-12.9.0.13-h9ab20c4_0
#   libcufft           conda-forge/linux-64::libcufft-11.4.0.6-h5888daf_0
#   libcufft-dev       conda-forge/linux-64::libcufft-dev-11.4.0.6-h5888daf_0
#   libcufile          conda-forge/linux-64::libcufile-1.14.0.30-h628e99a_0
#   libcufile-dev      conda-forge/linux-64::libcufile-dev-1.14.0.30-h5888daf_0
#   libcurand          conda-forge/linux-64::libcurand-10.3.10.19-h9ab20c4_0
#   libcurand-dev      conda-forge/linux-64::libcurand-dev-10.3.10.19-h9ab20c4_0
#   libcusolver        conda-forge/linux-64::libcusolver-11.7.4.40-h9ab20c4_0
#   libcusolver-dev    conda-forge/linux-64::libcusolver-dev-11.7.4.40-h9ab20c4_0
#   libcusparse        conda-forge/linux-64::libcusparse-12.5.9.5-h5888daf_0
#   libcusparse-dev    conda-forge/linux-64::libcusparse-dev-12.5.9.5-h5888daf_0
#   libedit            conda-forge/linux-64::libedit-3.1.20250104-pl5321h7949ede_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libgcc-devel_linu~ conda-forge/noarch::libgcc-devel_linux-64-13.3.0-hc03c837_102
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.1-hb9d3cd8_0
#   libglib            conda-forge/linux-64::libglib-2.84.1-h3618099_1
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.55-h3f2d84a_0
#   libiconv           conda-forge/linux-64::libiconv-1.18-h4ce23a2_1
#   libnl              conda-forge/linux-64::libnl-3.11.0-hb9d3cd8_0
#   libnpp             conda-forge/linux-64::libnpp-12.4.0.27-h9ab20c4_0
#   libnpp-dev         conda-forge/linux-64::libnpp-dev-12.4.0.27-h9ab20c4_0
#   libnuma            conda-forge/linux-64::libnuma-2.0.18-h4ab18f5_2
#   libnvfatbin        conda-forge/linux-64::libnvfatbin-12.9.19-h5888daf_0
#   libnvfatbin-dev    conda-forge/linux-64::libnvfatbin-dev-12.9.19-h5888daf_0
#   libnvjitlink       conda-forge/linux-64::libnvjitlink-12.9.41-h5888daf_0
#   libnvjitlink-dev   conda-forge/linux-64::libnvjitlink-dev-12.9.41-h5888daf_0
#   libnvjpeg          conda-forge/linux-64::libnvjpeg-12.4.0.16-h5888daf_0
#   libnvjpeg-dev      conda-forge/linux-64::libnvjpeg-dev-12.4.0.16-ha770c72_0
#   libopengl          conda-forge/linux-64::libopengl-1.7.0-ha4b6fd6_2
#   libpng             conda-forge/linux-64::libpng-1.6.47-h943b412_0
#   libsanitizer       conda-forge/linux-64::libsanitizer-13.3.0-he8ea267_2
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.1.0-h8f9b012_2
#   libstdcxx-devel_l~ conda-forge/noarch::libstdcxx-devel_linux-64-13.3.0-hc03c837_102
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-15.1.0-h4852527_2
#   libsystemd0        conda-forge/linux-64::libsystemd0-257.4-h4e0b6ca_1
#   libudev1           conda-forge/linux-64::libudev1-257.4-hbe16f8c_1
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.9.2-h65c71a3_0
#   libxkbfile         conda-forge/linux-64::libxkbfile-1.1.0-h166bdaf_1
#   libxml2            conda-forge/linux-64::libxml2-2.13.8-h4bc477f_0
#   lz4-c              conda-forge/linux-64::lz4-c-1.10.0-h5888daf_1
#   nsight-compute     conda-forge/linux-64::nsight-compute-2025.2.0.11-hb5ebaad_0
#   nspr               conda-forge/linux-64::nspr-4.36-h5888daf_0
#   nss                conda-forge/linux-64::nss-3.111-h159eef7_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.3-hb9d3cd8_0
#   opencl-headers     conda-forge/linux-64::opencl-headers-2024.10.24-h5888daf_0
#   pcre2              conda-forge/linux-64::pcre2-10.45-hc749103_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   rdma-core          conda-forge/linux-64::rdma-core-57.0-h5888daf_0
#   sysroot_linux-64   conda-forge/noarch::sysroot_linux-64-2.17-h0157908_18
#   wayland            conda-forge/linux-64::wayland-1.23.1-h3e06ad9_1
#   xcb-util           conda-forge/linux-64::xcb-util-0.4.1-hb711507_2
#   xcb-util-cursor    conda-forge/linux-64::xcb-util-cursor-0.1.5-hb9d3cd8_0
#   xcb-util-image     conda-forge/linux-64::xcb-util-image-0.4.0-hb711507_2
#   xcb-util-keysyms   conda-forge/linux-64::xcb-util-keysyms-0.4.1-hb711507_0
#   xcb-util-renderut~ conda-forge/linux-64::xcb-util-renderutil-0.3.10-hb711507_0
#   xcb-util-wm        conda-forge/linux-64::xcb-util-wm-0.4.2-hb711507_0
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.44-hb9d3cd8_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxcomposite conda-forge/linux-64::xorg-libxcomposite-0.4.6-hb9d3cd8_2
#   xorg-libxdamage    conda-forge/linux-64::xorg-libxdamage-1.1.6-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.1-hb9d3cd8_0
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.8.2-hb9d3cd8_0
#   xorg-libxrandr     conda-forge/linux-64::xorg-libxrandr-1.5.4-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxtst       conda-forge/linux-64::xorg-libxtst-1.2.5-hb9d3cd8_3
#   zstd               conda-forge/linux-64::zstd-1.5.7-hb8e6e7a_2
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  |            |   0%
# nsight-compute-2025. | 318.5 MB  |            |   0%
#
# libcusparse-12.5.9.5 | 199.2 MB  |            |   0%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  |            |   0%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   0%
#
#
#
#
# libcufft-11.4.0.6    | 154.3 MB  |            |   0%
#
#
#
#
#
# cuda-nsight-12.9.19  | 113.2 MB  |            |   0%
#
#
#
#
#
#
# cuda-nvvp-12.9.19    | 112.4 MB  |            |   0%
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.41   | 64.1 MB   |            |   0%
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   |            |   0%
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.41 | 29.1 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.7.4.4 | 192.4 MB  |            |   0%
#
# libcublas-12.9.0.13  | 445.8 MB  |            |   0%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   0%
#
# libcusparse-12.5.9.5 | 199.2 MB  |            |   0%
#
#
# libcublas-12.9.0.13  | 445.8 MB  |            |   0%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   0%
# nsight-compute-2025. | 318.5 MB  |            |   0%
#
# libcusparse-12.5.9.5 | 199.2 MB  |            |   0%
#
#
# libcublas-12.9.0.13  | 445.8 MB  |            |   0%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   0%
# libcublas-12.9.0.13  | 445.8 MB  |            |   0%
#
# libcusparse-12.5.9.5 | 199.2 MB  |            |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  |            |   1%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  |            |   0%
# nsight-compute-2025. | 318.5 MB  |            |   0%
#
# libcusparse-12.5.9.5 | 199.2 MB  |            |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  |            |   1%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  |            |   0%
# nsight-compute-2025. | 318.5 MB  |            |   0%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 1          |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 1          |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   1%
# libcublas-12.9.0.13  | 445.8 MB  |            |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 1          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 1          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   1%
# libcublas-12.9.0.13  | 445.8 MB  |            |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 1          |   2%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 1          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   1%
# libcublas-12.9.0.13  | 445.8 MB  |            |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 2          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 2          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   1%
# libcublas-12.9.0.13  | 445.8 MB  |            |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 2          |   3%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  |            |   1%
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 2          |   3%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 1          |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 2          |   2%
# nsight-compute-2025. | 318.5 MB  |            |   0%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 1          |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 2          |   3%
# nsight-compute-2025. | 318.5 MB  |            |   0%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 1          |   1%
# nsight-compute-2025. | 318.5 MB  |            |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 3          |   4%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   1%
# nsight-compute-2025. | 318.5 MB  |            |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 1          |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 3          |   3%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   1%
# nsight-compute-2025. | 318.5 MB  |            |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 3          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 4          |   4%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   1%
# nsight-compute-2025. | 318.5 MB  |            |   1%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 4          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 3          |   3%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   2%
# nsight-compute-2025. | 318.5 MB  |            |   1%
#
#
#
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 4          |   5%
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   2%
# nsight-compute-2025. | 318.5 MB  |            |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 2          |   2%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 4          |   5%
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   2%
# nsight-compute-2025. | 318.5 MB  |            |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 2          |   3%
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 3          |   4%
# nsight-compute-2025. | 318.5 MB  | 1          |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 2          |   3%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 4          |   4%
# nsight-compute-2025. | 318.5 MB  | 1          |   1%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 3          |   3%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 1          |   2%
# nsight-compute-2025. | 318.5 MB  | 1          |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 4          |   4%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 3          |   3%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   2%
# nsight-compute-2025. | 318.5 MB  | 1          |   1%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 4          |   4%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 3          |   4%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 5          |   6%
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 3          |   4%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 6          |   6%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   2%
# nsight-compute-2025. | 318.5 MB  | 1          |   2%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 6          |   6%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 3          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 4          |   5%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 4          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 4          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 6          |   7%
# nsight-compute-2025. | 318.5 MB  | 1          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 4          |   4%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   2%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 6          |   7%
# nsight-compute-2025. | 318.5 MB  | 1          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 4          |   5%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   2%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 7          |   7%
# nsight-compute-2025. | 318.5 MB  | 1          |   2%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 4          |   5%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 7          |   7%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 5          |   5%
# nsight-compute-2025. | 318.5 MB  | 1          |   2%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 7          |   8%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 5          |   6%
# nsight-compute-2025. | 318.5 MB  | 1          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 5          |   5%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 6          |   6%
# nsight-compute-2025. | 318.5 MB  | 2          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 5          |   6%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 6          |   6%
# nsight-compute-2025. | 318.5 MB  | 2          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 5          |   6%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 6          |   7%
# nsight-compute-2025. | 318.5 MB  | 2          |   2%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 5          |   6%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 7          |   7%
# nsight-compute-2025. | 318.5 MB  | 2          |   2%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 8          |   9%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 7          |   7%
# nsight-compute-2025. | 318.5 MB  | 2          |   2%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 9          |   9%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | 7          |   8%
# nsight-compute-2025. | 318.5 MB  | 2          |   2%
#
# libcublas-12.9.0.13  | 445.8 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 9          |   9%
# nsight-compute-2025. | 318.5 MB  | 2          |   3%
#
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 9          |  10%
# nsight-compute-2025. | 318.5 MB  | 2          |   3%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 6          |   7%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   3%
# nsight-compute-2025. | 318.5 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | 9          |  10%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 7          |   7%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   3%
# nsight-compute-2025. | 318.5 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #          |  10%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 7          |   7%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   3%
# nsight-compute-2025. | 318.5 MB  | 2          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #          |  10%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 7          |   8%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   3%
# nsight-compute-2025. | 318.5 MB  | 3          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #          |  11%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 7          |   8%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   3%
# nsight-compute-2025. | 318.5 MB  | 3          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #          |  11%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 8          |   8%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   4%
# nsight-compute-2025. | 318.5 MB  | 3          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #1         |  11%
#
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   4%
# nsight-compute-2025. | 318.5 MB  | 3          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #1         |  11%
#
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 8          |   9%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #1         |  12%
# nsight-compute-2025. | 318.5 MB  | 3          |   3%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 8          |   9%
# nsight-compute-2025. | 318.5 MB  | 3          |   3%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #1         |  12%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 3          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 8          |   9%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #1         |  12%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 4          |   4%
# nsight-compute-2025. | 318.5 MB  | 3          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 9          |   9%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #1         |  11% | 4          |   4%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  12%
# nsight-compute-2025. | 318.5 MB  | 3          |   4%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 9          |  10%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 4          |   4%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  12%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 9          |  10%
# libcublas-12.9.0.13  | 445.8 MB  | 4          |   5%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #1         |  12%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  12%
#
# libcusparse-12.5.9.5 | 199.2 MB  | 9          |  10%
# libcublas-12.9.0.13  | 445.8 MB  | 4          |   5%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #2         |  12%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #          |  10%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  12%
# libcublas-12.9.0.13  | 445.8 MB  | 4          |   5%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #2         |  12%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #          |  10%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  13%
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   5%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #2         |  13%
# nsight-compute-2025. | 318.5 MB  | 3          |   4%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  13%
#
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   5%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #2         |  13%
# nsight-compute-2025. | 318.5 MB  | 3          |   4%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  13%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #          |  11%
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #2         |  13%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #2         |  13%
# nsight-compute-2025. | 318.5 MB  | 4          |   4%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #3         |  13%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #3         |  13%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #          |  11%
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #3         |  13%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #3         |  13%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #1         |  11%
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   6%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #3         |  13%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #3         |  14%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #1         |  11%
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   6%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #3         |  14%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #3         |  14%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #1         |  11%
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   6%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #3         |  14%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #3         |  14%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #1         |  12%
# libcublas-12.9.0.13  | 445.8 MB  | 5          |   6%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #4         |  14%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #4         |  14%
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   6%
# nsight-compute-2025. | 318.5 MB  | 4          |   5%
#
#
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #4         |  14%
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   6%
# nsight-compute-2025. | 318.5 MB  | 4          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #4         |  14%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #4         |  15%
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   6%
# nsight-compute-2025. | 318.5 MB  | 4          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #4         |  15%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #4         |  15%
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   6%
# nsight-compute-2025. | 318.5 MB  | 5          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #4         |  15%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #5         |  15%
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   6%
# nsight-compute-2025. | 318.5 MB  | 5          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #5         |  15%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #2         |  13%
# nsight-compute-2025. | 318.5 MB  | 5          |   5%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #5         |  15%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #2         |  13%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #5         |  16%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #3         |  13%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #5         |  16%
# nsight-compute-2025. | 318.5 MB  | 5          |   5%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #6         |  16%
#
# libcublas-12.9.0.13  | 445.8 MB  | 6          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #5         |  16%
# nsight-compute-2025. | 318.5 MB  | 5          |   6%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #6         |  16%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #3         |  13%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   7%
# nsight-compute-2025. | 318.5 MB  | 5          |   6%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #6         |  16%
#
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   7%
# nsight-compute-2025. | 318.5 MB  | 5          |   6%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #6         |  17%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #3         |  14%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #6         |  17%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #3         |  14%
# nsight-compute-2025. | 318.5 MB  | 5          |   6%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #3         |  14%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #6         |  17%
# nsight-compute-2025. | 318.5 MB  | 5          |   6%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   7%
#
#
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  14%
# nsight-compute-2025. | 318.5 MB  | 5          |   6%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   8%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #7         |  17%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  14%
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   8%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #7         |  17%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  14%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #7         |  17%
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   8%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #7         |  18%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  14%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #7         |  17%
# libcublas-12.9.0.13  | 445.8 MB  | 7          |   8%
#
#
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  15%
# nsight-compute-2025. | 318.5 MB  | 6          |   6%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 8          |   8%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #8         |  18%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  15%
# nsight-compute-2025. | 318.5 MB  | 6          |   6%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 8          |   8%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #8         |  18%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  15%
# nsight-compute-2025. | 318.5 MB  | 6          |   6%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 8          |   8%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #8         |  19%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #4         |  15%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 8          |   8%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #8         |  19%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  15%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 8          |   9%
# nsight-compute-2025. | 318.5 MB  | 6          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #8         |  19%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  15%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 8          |   9%
# nsight-compute-2025. | 318.5 MB  | 6          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #9         |  19%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  15%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 8          |   9%
# nsight-compute-2025. | 318.5 MB  | 6          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  15%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #9         |  19%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |   9%
# nsight-compute-2025. | 318.5 MB  | 6          |   7%
#
#
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #8         |  18%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  16%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |   9%
# nsight-compute-2025. | 318.5 MB  | 6          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  16%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #9         |  20%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |   9%
# nsight-compute-2025. | 318.5 MB  | 6          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  16%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | #9         |  20%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |   9%
# nsight-compute-2025. | 318.5 MB  | 7          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #5         |  16%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##         |  20%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |  10%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #6         |  16%
# nsight-compute-2025. | 318.5 MB  | 7          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##         |  20%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |  10%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #6         |  16%
# nsight-compute-2025. | 318.5 MB  | 7          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##         |  21%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |  10%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #6         |  17%
# nsight-compute-2025. | 318.5 MB  | 7          |   7%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##         |  21%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | 9          |  10%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##         |  21%
# nsight-compute-2025. | 318.5 MB  | 7          |   7%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #6         |  17%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #          |  10%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##1        |  21%
# nsight-compute-2025. | 318.5 MB  | 7          |   8%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #6         |  17%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #          |  10%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##1        |  21%
# nsight-compute-2025. | 318.5 MB  | 7          |   8%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #7         |  17%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #9         |  20%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #          |  10%
# nsight-compute-2025. | 318.5 MB  | 7          |   8%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #9         |  20%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #7         |  17%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #          |  11%
# nsight-compute-2025. | 318.5 MB  | 7          |   8%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | #9         |  20%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #7         |  17%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##2        |  22%
# libcublas-12.9.0.13  | 445.8 MB  | #          |  11%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | ##         |  20%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #7         |  18%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #          |  11%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | ##         |  20%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #7         |  18%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##2        |  23%
# libcublas-12.9.0.13  | 445.8 MB  | #          |  11%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | ##         |  20%
# nsight-compute-2025. | 318.5 MB  | 8          |   8%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #7         |  18%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #          |  11%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | ##         |  21%
# nsight-compute-2025. | 318.5 MB  | 8          |   8%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #8         |  18%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #1         |  11%
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #1         |  11%
#
#
# libcusolver-11.7.4.4 | 192.4 MB  | ##3        |  23%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #8         |  18%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | ##1        |  21%
# nsight-compute-2025. | 318.5 MB  | 8          |   9%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #1         |  11%
#
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | ##1        |  21%
# nsight-compute-2025. | 318.5 MB  | 8          |   9%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #1         |  11%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #8         |  18%
#
#
#
# libnpp-12.4.0.27     | 167.2 MB  | ##1        |  21%
# nsight-compute-2025. | 318.5 MB  | 8          |   9%
#
#
# libcublas-12.9.0.13  | 445.8 MB  | #1         |  12%
#
# libcusparse-12.5.9.5 | 199.2 MB  | #8         |  19%
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.41 | 29.1 MB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.41 | 29.1 MB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.41 | 29.1 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ####2      |  43%
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.0 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########7  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.41 | 29.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | #####2     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | 4          |   4%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #          |  11%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #4         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ##2        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ########3  |  84%
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ##4        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ########6  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.41 | 29.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ####       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #####      |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
# gcc_impl_linux-64-13 | 63.7 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ######1    |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# gds-tools-1.14.0.30  | 37.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ######6    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | #######1   |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | #######6   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #######9   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #####9     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ########1  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ########8  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ########3  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ######4    |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.9 | 23.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.2 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gxx_impl_linux-64-13 | 12.7 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-dev_linux- | 13.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sysroot_linux-64-2.1 | 14.5 MB   | ########## | 100%
# nsight-compute-2025. | 318.5 MB  | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-impl-12.9. | 20.4 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-12.9.0.13  | 445.8 MB  | ########## | 100% [A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                      A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
